# %% [markdown]
# <a href="https://colab.research.google.com/github/BHARGAVIGHEGDE/15_days_roadmap_on_DSA/blob/main/sample1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#To make changes in the image

# %%
import cv2
import numpy as np
img=cv2.imread("/robo1.jpg")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FFA5CA70580>

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite("graygr.png",gray)
# Out:
# True

# %%
cv2_imshow(cv2.imread("graygray.png"))
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FFA5CB72FD0>

# %%
thresh=cv2.threshold(gray,185,200,cv2.THRESH_BINARY)[1]

# %%
cv2.imwrite("aa.png",thresh)
# Out:
# True

# %%
cv2_imshow(thresh)
# Out:
# <PIL.Image.Image image mode=L size=300x168 at 0x7FFA526B8A00>

# %%
print(img.size)
# Out:
# 151200

# %%
print(img.shape)
# Out:
# (168, 300, 3)

# %%
cv2.imwrite("sample_robo.png",img)
# Out:
# True

# %%
print(img.dtype)
# Out:
# uint8

# %%
cv2.waitKey(0)
# Out:
# -1

# %%
cv2.destroyAllWindows()
